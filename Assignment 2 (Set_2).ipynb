# %% [markdown]
# # Question No 1

# %%
from scipy import stats
from scipy.stats import norm

# %%
Z=(50-45)/8
Z
# Out:
# 0.625

# %%
1-stats.norm.cdf(abs(0.625))
# Out:
# 0.26598552904870054

# %%
p_value=stats.norm.cdf(abs(0.625))
p_value
# Out:
# 0.7340144709512995

# %%
1-p_value
# Out:
# 0.26598552904870054

# %% [markdown]
# # Question No 2

# %%
1-stats.norm.cdf(44,loc=38,scale=6)
# Out:
# 0.15865525393145707

# %%
stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,6)
#Answer of A :
# Out:
# 0.3413447460685429

# %%
stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %%
400*stats.norm.cdf(30,38,6)
#Answer of B :
# Out:
# 36.484487890347154

# %% [markdown]
# # Question No 4

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# # Question No 5

# %%
import numpy as np

# %%
Mean = 5+7
print('Mean profit is',Mean*45,'Million')
# Out:
# Mean profit is 540 Million

# %%
SD=np.sqrt((9)+(16))
print('Standard Deviation is',SD*45,'Million')
# Out:
# Standard Deviation is 225.0 Million

# %%
#Answer of A
print('Range is',stats.norm.interval(0.95,540,225),'in million')
# Out:
# Range is (99.00810347848784, 980.9918965215122) in million

# %%
X=540+(-1.645)*(225)

# %%
#Answer Of B
print('5th percentile of profit is',np.round(X))
# Out:
# 5th percentile of profit is 170.0

# %%
#Answer Of C
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086
